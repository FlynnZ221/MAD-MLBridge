# %%
import numpy as np
import pandas as pd
import os
import random
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.layers import LeakyReLU
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

import wandb
from wandb.integration.keras import WandbCallback
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import backend as K

path_to_snp = "../data/SNP/"
# Out:
# 2024-12-02 15:00:11.868132: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
config={
        "epochs": 100,
        "batch_size": 32,
        "learning_rate": 1e-5,
        "architecture": "DeepSNP",
        "dropout": 0.2,
        # "l2": 1e-2,
        "seed": None,
}

# %%
wandb.init(
    project="SNP_alone_feature_selected_mi_DeepSNP",
    name=f"DeepSNP_pl_1_32_5_2",
    config=config
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: jaredzwx221 (jaredzwx221-carnegie-mellon-univeristy). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/root/MADDi/train/wandb/run-20241202_150016-rlz2txny</code>
# Syncing run <strong><a href='https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP/runs/rlz2txny' target="_blank">DeepSNP_pl_1_32_5_2</a></strong> to <a href='https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP' target="_blank">https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP</a>
#  View run at <a href='https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP/runs/rlz2txny' target="_blank">https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP/runs/rlz2txny</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP/runs/rlz2txny?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def reset_random_seeds(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

# def improved_model(input_shape, output_classes):
#     model = Sequential([
#         Dense(128, input_shape=(input_shape,), kernel_regularizer=l2(0.001)),
#         LeakyReLU(alpha=0.1),
#         Dropout(0.5),
#         Dense(64, kernel_regularizer=l2(1e-6)),
#         LeakyReLU(alpha=0.1),
#         Dropout(0.5),
#         Dense(32, kernel_regularizer=l2(1e-6)),
#         LeakyReLU(alpha=0.1),
#         Dropout(0.3),
#         Dense(32, kernel_regularizer=l2(1e-6)),
#         LeakyReLU(alpha=0.1),
#         Dropout(0.3),
#         Dense(output_classes, activation='softmax')
#     ])
#     model.compile(
#         optimizer=Adam(learning_rate=config['learning_rate'], clipvalue=1.0),
#         loss="sparse_categorical_crossentropy",
#         metrics=["sparse_categorical_accuracy"]
#     )
#     return model

def shallow_model(input_shape, output_classes):
    model = Sequential([
        Dense(128, input_shape=(input_shape,), activation="relu", kernel_regularizer=l2(config['l2'])),
        Dropout(config["dropout"]),
        # Dense(64, activation="relu", kernel_regularizer=l2(config['l2'])),
        Dense(64, activation="relu"),
        Dropout(config["dropout"]),
        Dense(32, activation="relu"),
        Dropout(config["dropout"]-0.1),
        Dense(32, activation="relu"),
        Dropout(config["dropout"]-0.1),
        Dense(output_classes, activation="softmax")
    ])
    model.compile(
        optimizer=Adam(learning_rate=config['learning_rate']),
        loss="sparse_categorical_crossentropy",
        metrics=["sparse_categorical_accuracy"]
    )
    return model

def even_shallow_model(input_shape, output_classes):
    model = Sequential([
        Dense(64, input_shape=(input_shape,), activation="relu"),
        Dropout(config["dropout"]),
        # Dense(64, activation="relu", kernel_regularizer=l2(config['l2'])),
        Dense(32, activation="relu"),
        Dropout(config["dropout"]),
        Dense(16, activation="relu"),
        Dropout(config["dropout"]-0.1),
        Dense(16, activation="relu"),
        Dropout(config["dropout"]-0.1),
        Dense(output_classes, activation="softmax")
    ])
    model.compile(
        optimizer=Adam(learning_rate=config['learning_rate']),
        loss="sparse_categorical_crossentropy",
        metrics=["sparse_categorical_accuracy"]
    )
    return model

def DeepSNP(input_shape, output_classes):
    model = Sequential([
        Conv1D(64, kernel_size=5, activation="relu", input_shape=(input_shape, 1)),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(config["dropout"]),

        Conv1D(128, kernel_size=3, activation="relu"),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(config["dropout"]),

        Flatten(),
        Dense(128, activation="relu"),
        BatchNormalization(),
        Dropout(config["dropout"]),

        Dense(output_classes, activation="softmax")
    ])

    model.compile(
        optimizer=Adam(learning_rate=config['learning_rate']),
        loss="sparse_categorical_crossentropy",
        metrics=["sparse_categorical_accuracy"]
    )
    return model

def evaluate_model(model, X_test, y_test):
    score = model.evaluate(X_test, y_test, verbose=0)
    print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')

    predictions = model.predict(X_test)
    true_labels = np.argmax(to_categorical(y_test, num_classes=3), axis=1)
    predicted_labels = np.argmax(predictions, axis=1)

    report = classification_report(true_labels, predicted_labels, output_dict=True)
    return score[1], report["macro avg"]["precision"], report["macro avg"]["recall"], report["macro avg"]["f1-score"]

# %%
vcf_sele = pd.read_pickle(path_to_snp + "vcf_select_mi.pkl")

vcf_sele
# Out:
#       label     Subject  Group  12373_89763  56273  367261_81730  105448  \
# 0         0  011_S_0002    0.0            0      0             0       0
# 3         1  011_S_0002    0.0            0      0             0       0
# 5         0  011_S_0008    0.0            0      0             0       0
# 8         1  011_S_0008    0.0            0      0             0       0
# 9         0  100_S_0015    0.0            0      0             2       0
# ...     ...         ...    ...          ...    ...           ...     ...
# 1698      1  072_S_4610    1.0            0      1             0       0
# 1699      1  072_S_4613    1.0            0      0             0       0
# 1700      1  153_S_4621    1.0            0      2             1       1
# 1702      2  005_S_4707    2.0            0      1             1       0
# 1703      2  002_S_4171    2.0            0      1             0       1
#
#       375979  521667  100275_124934  ...  211299  355098_174869  9425_152424  \
# 0          0       1              0  ...       0              0            0
# 3          0       1              0  ...       0              0            0
# 5          0       2              0  ...       0              0            0
# 8          0       2              0  ...       0              0            0
# 9          0       1              0  ...       0              0            0
# ...      ...     ...            ...  ...     ...            ...          ...
# 1698       0       2              0  ...       0              0            0
# 1699       0       1              0  ...       0              0            0
# 1700       0       0              0  ...       0              1            0
# 1702       0       1              0  ...       1              0            0
# 1703       1       0              0  ...       0              0            0
#
#       138682_109508  261887  88681  249988  11232  78936  415684
# 0                 0       2      0       0      2      0       0
# 3                 0       2      0       0      2      0       0
# 5                 0       1      1       0      2      0       0
# 8                 0       1      1       0      2      0       0
# 9                 0       2      1       1      2      0       1
# ...             ...     ...    ...     ...    ...    ...     ...
# 1698              0       1      1       0      2      0       0
# 1699              0       2      2       0      0      0       1
# 1700              0       2      0       0      1      0       2
# 1702              0       2      1       1      2      0       1
# 1703              0       1      1       0      1      0       0
#
# [954 rows x 16336 columns]

# %%
cols = list(set(vcf_sele.columns) - set(["Subject", "Group", "label"]))
X = vcf_sele[cols]
y = vcf_sele["label"].astype(int)

X_df = pd.DataFrame(X)
y_df = pd.DataFrame(y)
y_df.rename(columns={"label": "label"}, inplace=True)

data = pd.concat([X_df, y_df], axis=1)

# Over-sampling
class_counts = y_df["label"].value_counts()
max_count = class_counts.max()

oversampled_data = []
for label, count in class_counts.items():
    class_data = data[data["label"] == label]
    if count < max_count:
        sampled_data = class_data.sample(max_count - count, replace=True, random_state=42)
        oversampled_data.append(sampled_data)

oversampled_data = pd.concat(oversampled_data, axis=0)
balanced_data = pd.concat([data, oversampled_data], axis=0)

X_balanced = balanced_data.iloc[:, :-1]
y_balanced = balanced_data.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(
    X_balanced, y_balanced, test_size=0.1, stratify=y_balanced, random_state=42
)

print("After sampling and splitting:")
print("Train label distribution:")
print(y_train.value_counts() / len(y_train))
print("Test label distribution:")
print(y_test.value_counts() / len(y_test))

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
assert list(X_train.columns) == list(X_test.columns), "Column names do not match between X_train and X_test"
# Out:
# After sampling and splitting:
# Train label distribution:
# label
# 0    0.333929
# 1    0.333036
# 2    0.333036
# Name: count, dtype: float64
# Test label distribution:
# label
# 2    0.336
# 1    0.336
# 0    0.328
# Name: count, dtype: float64
# (1120, 16333)
# (1120,)
# (125, 16333)
# (125,)

# %%
# cols = list(set(vcf_sele.columns) - set(["Subject", "Group", "label"]))
# X = vcf_sele[cols]
# y = vcf_sele["label"].astype(int).values

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y)

# y_train = pd.DataFrame(y_train)
# y_test = pd.DataFrame(y_test)

# %%
# X_train = X_train.reset_index(drop=True)
# y_train = y_train.reset_index(drop=True)

# print("Before sampling:")
# print(y_train.value_counts()/len(y_train))
# X_train_df = pd.DataFrame(X_train)
# y_train_df = pd.DataFrame(y_train)
# y_train_df.rename(columns={0: 'label'}, inplace=True)
# original_columns = X_train_df.columns
# data = pd.concat([X_train_df, y_train_df], axis=1)

# class_counts = y_train_df["label"].value_counts()
# max_count = class_counts.max()

# oversampled_data = []
# for label, count in class_counts.items():
#     class_data = data[data["label"] == label]
    
#     if count < max_count:
#         sampled_data = class_data.sample(max_count - count, replace=True, random_state=42)
#         oversampled_data.append(sampled_data)

# oversampled_data = pd.concat(oversampled_data, axis=0)
# balanced_data = pd.concat([data, oversampled_data], axis=0)

# X_train = balanced_data.iloc[:, :-1].values
# y_train = balanced_data.iloc[:, -1].values

# X_train = pd.DataFrame(X_train)
# y_train = pd.DataFrame(y_train)

# X_train.columns = original_columns
# y_train.rename(columns={0: 'label'}, inplace=True)

# print("After sampling:")
# print(y_train.value_counts()/len(y_train))

# print(X_train.shape)
# print(y_train.shape)
# print(X_test.shape)
# print(y_test.shape)
# assert list(X_train.columns) == list(X_test.columns), "Column names do not match between X_train and X_test"

# %%
# X_train = pd.read_pickle(path_to_snp + "X_train_vcf.pkl")
# y_train = pd.read_pickle(path_to_snp + "y_train_vcf.pkl")
# X_test = pd.read_pickle(path_to_snp + "X_test_vcf.pkl")
# y_test = pd.read_pickle(path_to_snp + "y_test_vcf.pkl")

# %%
X_train.columns, X_test.columns
# Out:
# (Index(['190641', '166764', '507965', '162937', '175951', '216154',
#         '156847_139816', '10043', '27574_67442', '421463',
#         ...
#         '69073', '585184', '96051', '514217', '241315', '131733',
#         '147775_73365', '508050', '279543', '187339'],
#        dtype='object', length=16333),
#  Index(['190641', '166764', '507965', '162937', '175951', '216154',
#         '156847_139816', '10043', '27574_67442', '421463',
#         ...
#         '69073', '585184', '96051', '514217', '241315', '131733',
#         '147775_73365', '508050', '279543', '187339'],
#        dtype='object', length=16333))

# %%
print(y_test.value_counts()/len(y_test))
# Out:
# label
# 2    0.336
# 1    0.336
# 0    0.328
# Name: count, dtype: float64

# %%
# class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
# class_weight_dict = dict(enumerate(class_weights))
# class_weight_dict

# %%
acc, precision, recall, f1 = [], [], [], []

# %%
seeds = [87, 49, 114, 38, 4]

# %%
# seeds = random.sample(range(1, 200), 5)

# seeds

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
# def lr_schedule(epoch, lr):
#     initial_lr = 0.001
#     decay_rate = 0.1
#     decay_epoch = 10
#     if epoch % decay_epoch == 0 and epoch != 0:
#         return lr * decay_rate
#     return lr

# lr_scheduler = LearningRateScheduler(lr_schedule)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7
)

class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        optimizer = self.model.optimizer
        current_lr = float(K.get_value(optimizer.learning_rate))
        
        print(f"\nEpoch {epoch + 1}: Current Learning Rate is {current_lr:.6f}")
        
        wandb.log({"learning_rate": current_lr})

# %%
# Train
for seed in seeds:
    reset_random_seeds(seed)
    print(f"Training model with seed {seed}...")
    wandb.config.seed = seed

    # Build and train model
    model = DeepSNP(input_shape=X_train.shape[1], output_classes=3)
    history = model.fit(
        X_train, y_train,
        epochs=config['epochs'],
        batch_size=config['batch_size'],
        validation_split=0.1,
        # class_weight=class_weight_dict,
        verbose=1,
        callbacks=[WandbCallback(
            monitor='val_loss',
            save_model=False,
            log_weights=False,
            log_gradients=False
        ), reduce_lr, LearningRateLogger()]
    )
    
    # Evaluate model
    accuracy, prec, rec, f1_score = evaluate_model(model, X_test, y_test)
    acc.append(accuracy)
    precision.append(prec)
    recall.append(rec)
    f1.append(f1_score)
    
    # Log metrics to wandb
    wandb.log({
        "accuracy": accuracy,
        "precision": prec,
        "recall": rec,
        "f1_score": f1_score,
    })
    
wandb.finish()
# Out:
# Training model with seed 87...
# 2024-12-02 15:00:26.399484: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-02 15:00:27.109861: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20825 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:dd:00.0, compute capability: 7.5
# wandb: WARNING WandbCallback is deprecated and will be removed in a future release. Please use the WandbMetricsLogger, WandbModelCheckpoint, and WandbEvalCallback callbacks instead. See https://docs.wandb.ai/guides/integrations/keras for more information.
# Epoch 1/100
# 2024-12-02 15:00:29.632065: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
#  6/32 [====>.........................] - ETA: 1s - loss: 1.6441 - sparse_categorical_accuracy: 0.3438WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0240s vs `on_train_batch_end` time: 0.0289s). Check your callbacks.
# 32/32 [==============================] - ETA: 0s - loss: 1.5819 - sparse_categorical_accuracy: 0.3631
# Epoch 1: Current Learning Rate is 0.000010
# 32/32 [==============================] - 5s 67ms/step - loss: 1.5819 - sparse_categorical_accuracy: 0.3631 - val_loss: 1.1358 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 2/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.7247 - sparse_categorical_accuracy: 0.6986
# Epoch 2: Current Learning Rate is 0.000010
# 32/32 [==============================] - 2s 57ms/step - loss: 0.7267 - sparse_categorical_accuracy: 0.6994 - val_loss: 1.6891 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 3/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.5538 - sparse_categorical_accuracy: 0.7833
# Epoch 3: Current Learning Rate is 0.000010
# 32/32 [==============================] - 2s 56ms/step - loss: 0.5557 - sparse_categorical_accuracy: 0.7817 - val_loss: 2.3692 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 4/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.5093 - sparse_categorical_accuracy: 0.8256
# Epoch 4: Current Learning Rate is 0.000010
# 32/32 [==============================] - 2s 54ms/step - loss: 0.5182 - sparse_categorical_accuracy: 0.8224 - val_loss: 2.3806 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 5/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3073 - sparse_categorical_accuracy: 0.8522 - val_loss: 1.7212 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 40/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2904 - sparse_categorical_accuracy: 0.8679
# Epoch 40: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.8671 - val_loss: 1.7175 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 41/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2817 - sparse_categorical_accuracy: 0.8599
# Epoch 41: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2826 - sparse_categorical_accuracy: 0.8601 - val_loss: 1.7134 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 42/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2825 - sparse_categorical_accuracy: 0.8760
# Epoch 42: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2843 - sparse_categorical_accuracy: 0.8740 - val_loss: 1.7151 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 43/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2970 - sparse_categorical_accuracy: 0.8599
# Epoch 43: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2997 - sparse_categorical_accuracy: 0.8601 - val_loss: 1.7171 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 44/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2935 - sparse_categorical_accuracy: 0.8619
# Epoch 44: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2930 - sparse_categorical_accuracy: 0.8621 - val_loss: 1.7178 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 45/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2825 - sparse_categorical_accuracy: 0.8679
# Epoch 45: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2855 - sparse_categorical_accuracy: 0.8671 - val_loss: 1.7183 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 46/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2911 - sparse_categorical_accuracy: 0.8599
# Epoch 46: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2903 - sparse_categorical_accuracy: 0.8611 - val_loss: 1.7186 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 47/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3098 - sparse_categorical_accuracy: 0.8538
# Epoch 47: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3075 - sparse_categorical_accuracy: 0.8552 - val_loss: 1.7202 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 48/100
# Epoch 57/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3044 - sparse_categorical_accuracy: 0.8619
# Epoch 57: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3041 - sparse_categorical_accuracy: 0.8621 - val_loss: 1.7254 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 58/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2954 - sparse_categorical_accuracy: 0.8558
# Epoch 58: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2936 - sparse_categorical_accuracy: 0.8571 - val_loss: 1.7239 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 59/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2739 - sparse_categorical_accuracy: 0.8740
# Epoch 59: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2727 - sparse_categorical_accuracy: 0.8750 - val_loss: 1.7234 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 60/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2843 - sparse_categorical_accuracy: 0.8740
# Epoch 60: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.2876 - sparse_categorical_accuracy: 0.8730 - val_loss: 1.7231 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 61/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2818 - sparse_categorical_accuracy: 0.8639
# Epoch 61: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2805 - sparse_categorical_accuracy: 0.8651 - val_loss: 1.7244 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 62/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3109 - sparse_categorical_accuracy: 0.8508
# Epoch 62: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3100 - sparse_categorical_accuracy: 0.8502 - val_loss: 1.7249 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 63/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3161 - sparse_categorical_accuracy: 0.8528
# Epoch 63: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3204 - sparse_categorical_accuracy: 0.8522 - val_loss: 1.7220 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 64/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2982 - sparse_categorical_accuracy: 0.8569
# Epoch 64: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3015 - sparse_categorical_accuracy: 0.8562 - val_loss: 1.7253 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 65/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2805 - sparse_categorical_accuracy: 0.8710
# Epoch 65: Current Learning Rate is 0.000000
# Epoch 74/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3065 - sparse_categorical_accuracy: 0.8508
# Epoch 74: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3074 - sparse_categorical_accuracy: 0.8512 - val_loss: 1.7308 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 75/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2905 - sparse_categorical_accuracy: 0.8518
# Epoch 75: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2877 - sparse_categorical_accuracy: 0.8542 - val_loss: 1.7319 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 76/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3071 - sparse_categorical_accuracy: 0.8558
# Epoch 76: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3054 - sparse_categorical_accuracy: 0.8562 - val_loss: 1.7302 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 77/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2976 - sparse_categorical_accuracy: 0.8669
# Epoch 77: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2936 - sparse_categorical_accuracy: 0.8690 - val_loss: 1.7344 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 78/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2803 - sparse_categorical_accuracy: 0.8619
# Epoch 78: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2776 - sparse_categorical_accuracy: 0.8641 - val_loss: 1.7345 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 79/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2971 - sparse_categorical_accuracy: 0.8579
# Epoch 79: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2941 - sparse_categorical_accuracy: 0.8601 - val_loss: 1.7332 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 80/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2931 - sparse_categorical_accuracy: 0.8548
# Epoch 80: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2944 - sparse_categorical_accuracy: 0.8532 - val_loss: 1.7363 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 81/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2879 - sparse_categorical_accuracy: 0.8558
# Epoch 81: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.2853 - sparse_categorical_accuracy: 0.8571 - val_loss: 1.7354 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 82/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3009 - sparse_categorical_accuracy: 0.8589
# Epoch 82: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2994 - sparse_categorical_accuracy: 0.8601 - val_loss: 1.7338 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 83/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3010 - sparse_categorical_accuracy: 0.8589
# Epoch 83: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3018 - sparse_categorical_accuracy: 0.8581 - val_loss: 1.7383 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 84/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2973 - sparse_categorical_accuracy: 0.8639
# Epoch 84: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2952 - sparse_categorical_accuracy: 0.8651 - val_loss: 1.7396 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 85/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2847 - sparse_categorical_accuracy: 0.8558
# Epoch 85: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2827 - sparse_categorical_accuracy: 0.8571 - val_loss: 1.7383 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 86/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2849 - sparse_categorical_accuracy: 0.8700
# Epoch 86: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2861 - sparse_categorical_accuracy: 0.8690 - val_loss: 1.7399 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 87/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2798 - sparse_categorical_accuracy: 0.8700
# Epoch 87: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.2813 - sparse_categorical_accuracy: 0.8681 - val_loss: 1.7406 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 88/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2742 - sparse_categorical_accuracy: 0.8750
# Epoch 88: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2738 - sparse_categorical_accuracy: 0.8750 - val_loss: 1.7405 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 89/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3011 - sparse_categorical_accuracy: 0.8619
# Epoch 89: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3023 - sparse_categorical_accuracy: 0.8611 - val_loss: 1.7442 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 90/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2843 - sparse_categorical_accuracy: 0.8649
# Epoch 90: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2882 - sparse_categorical_accuracy: 0.8631 - val_loss: 1.7394 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 91/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3012 - sparse_categorical_accuracy: 0.8558
# Epoch 91: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.3054 - sparse_categorical_accuracy: 0.8532 - val_loss: 1.7398 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 92/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3081 - sparse_categorical_accuracy: 0.8599
# Epoch 92: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3095 - sparse_categorical_accuracy: 0.8591 - val_loss: 1.7415 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 93/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2914 - sparse_categorical_accuracy: 0.8710
# Epoch 93: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 57ms/step - loss: 0.2975 - sparse_categorical_accuracy: 0.8661 - val_loss: 1.7398 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 94/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2793 - sparse_categorical_accuracy: 0.8710
# Epoch 94: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2812 - sparse_categorical_accuracy: 0.8700 - val_loss: 1.7357 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 95/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2882 - sparse_categorical_accuracy: 0.8720
# Epoch 95: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2866 - sparse_categorical_accuracy: 0.8730 - val_loss: 1.7375 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 96/100
# 32/32 [==============================] - ETA: 0s - loss: 0.2917 - sparse_categorical_accuracy: 0.8641
# Epoch 96: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2917 - sparse_categorical_accuracy: 0.8641 - val_loss: 1.7416 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 97/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2844 - sparse_categorical_accuracy: 0.8649
# Epoch 97: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2877 - sparse_categorical_accuracy: 0.8641 - val_loss: 1.7422 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 98/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2933 - sparse_categorical_accuracy: 0.8579
# Epoch 98: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2908 - sparse_categorical_accuracy: 0.8591 - val_loss: 1.7419 - val_sparse_categorical_accuracy: 0.4911 - lr: 1.0000e-07
# Epoch 99/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2741 - sparse_categorical_accuracy: 0.8679
# Epoch 99: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2711 - sparse_categorical_accuracy: 0.8700 - val_loss: 1.7451 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 100/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2918 - sparse_categorical_accuracy: 0.8690
# Epoch 100: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2885 - sparse_categorical_accuracy: 0.8710 - val_loss: 1.7452 - val_sparse_categorical_accuracy: 0.5000 - lr: 1.0000e-07
# Test loss: 1.7796536684036255 / Test accuracy: 0.5040000081062317
# 4/4 [==============================] - 0s 12ms/step
# Training model with seed 49...
# Epoch 1/100
#  6/32 [====>.........................] - ETA: 1s - loss: 1.7366 - sparse_categorical_accuracy: 0.3594WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0213s vs `on_train_batch_end` time: 0.0312s). Check your callbacks.
# 31/32 [============================>.] - ETA: 0s - loss: 1.5978 - sparse_categorical_accuracy: 0.3720
# Epoch 1: Current Learning Rate is 0.000010
# 32/32 [==============================] - 3s 61ms/step - loss: 1.5953 - sparse_categorical_accuracy: 0.3740 - val_loss: 1.2767 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 2/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.8024 - sparse_categorical_accuracy: 0.6764
# Epoch 2: Current Learning Rate is 0.000010
# 32/32 [==============================] - 2s 53ms/step - loss: 0.8095 - sparse_categorical_accuracy: 0.6746 - val_loss: 1.7596 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 3/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.6764 - sparse_categorical_accuracy: 0.7440
# Epoch 3: Current Learning Rate is 0.000010
# 32/32 [==============================] - 2s 56ms/step - loss: 0.6742 - sparse_categorical_accuracy: 0.7460 - val_loss: 2.1194 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 4/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.5154 - sparse_categorical_accuracy: 0.8054
# Epoch 4: Current Learning Rate is 0.000010
# 32/32 [==============================] - 2s 53ms/step - loss: 0.5197 - sparse_categorical_accuracy: 0.8046 - val_loss: 2.6398 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 5/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.5328 - sparse_categorical_accuracy: 0.7994
# Epoch 5: Current Learning Rate is 0.000010
# 32/32 [==============================] - 2s 53ms/step - loss: 0.5284 - sparse_categorical_accuracy: 0.8016 - val_loss: 2.6257 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 6/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.4912 - sparse_categorical_accuracy: 0.8327
# Epoch 6: Current Learning Rate is 0.000005
# 32/32 [==============================] - 2s 54ms/step - loss: 0.4950 - sparse_categorical_accuracy: 0.8304 - val_loss: 2.9958 - val_sparse_categorical_accuracy: 0.3571 - lr: 1.0000e-05
# Epoch 7/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.4301 - sparse_categorical_accuracy: 0.8327
# Epoch 7: Current Learning Rate is 0.000005
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3181 - sparse_categorical_accuracy: 0.8611 - val_loss: 1.8950 - val_sparse_categorical_accuracy: 0.4821 - lr: 1.5625e-07
# Epoch 34/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3047 - sparse_categorical_accuracy: 0.8720
# Epoch 34: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3063 - sparse_categorical_accuracy: 0.8710 - val_loss: 1.8985 - val_sparse_categorical_accuracy: 0.4821 - lr: 1.5625e-07
# Epoch 35/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3227 - sparse_categorical_accuracy: 0.8498
# Epoch 35: Current Learning Rate is 0.000000
# ...
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2953 - sparse_categorical_accuracy: 0.8621 - val_loss: 1.7273 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 63/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2887 - sparse_categorical_accuracy: 0.8659
# Epoch 63: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2889 - sparse_categorical_accuracy: 0.8661 - val_loss: 1.7274 - val_sparse_categorical_accuracy: 0.5268 - lr: 1.0000e-07
# Epoch 64/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2940 - sparse_categorical_accuracy: 0.8609
# Epoch 64: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2942 - sparse_categorical_accuracy: 0.8611 - val_loss: 1.7275 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 65/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3117 - sparse_categorical_accuracy: 0.8599
# Epoch 65: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.3104 - sparse_categorical_accuracy: 0.8601 - val_loss: 1.7265 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 66/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2710 - sparse_categorical_accuracy: 0.8690
# Epoch 66: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2762 - sparse_categorical_accuracy: 0.8651 - val_loss: 1.7238 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 67/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2820 - sparse_categorical_accuracy: 0.8609
# Epoch 67: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2839 - sparse_categorical_accuracy: 0.8601 - val_loss: 1.7235 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 68/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2904 - sparse_categorical_accuracy: 0.8629
# Epoch 68: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2898 - sparse_categorical_accuracy: 0.8631 - val_loss: 1.7234 - val_sparse_categorical_accuracy: 0.5268 - lr: 1.0000e-07
# Epoch 69/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3071 - sparse_categorical_accuracy: 0.8528
# Epoch 69: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.3088 - sparse_categorical_accuracy: 0.8502 - val_loss: 1.7224 - val_sparse_categorical_accuracy: 0.5268 - lr: 1.0000e-07
# Epoch 70/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3124 - sparse_categorical_accuracy: 0.8538
# Epoch 70: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.3131 - sparse_categorical_accuracy: 0.8542 - val_loss: 1.7235 - val_sparse_categorical_accuracy: 0.5268 - lr: 1.0000e-07
# Epoch 71/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3023 - sparse_categorical_accuracy: 0.8569
# Epoch 71: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3003 - sparse_categorical_accuracy: 0.8571 - val_loss: 1.7220 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 72/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2940 - sparse_categorical_accuracy: 0.8579
# Epoch 72: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2996 - sparse_categorical_accuracy: 0.8552 - val_loss: 1.7228 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 73/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2726 - sparse_categorical_accuracy: 0.8730
# Epoch 73: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2693 - sparse_categorical_accuracy: 0.8750 - val_loss: 1.7236 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 74/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3088 - sparse_categorical_accuracy: 0.8619
# Epoch 74: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3103 - sparse_categorical_accuracy: 0.8611 - val_loss: 1.7223 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 75/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3104 - sparse_categorical_accuracy: 0.8528
# Epoch 75: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.3100 - sparse_categorical_accuracy: 0.8522 - val_loss: 1.7251 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 76/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2930 - sparse_categorical_accuracy: 0.8619
# Epoch 76: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2893 - sparse_categorical_accuracy: 0.8641 - val_loss: 1.7291 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 77/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3063 - sparse_categorical_accuracy: 0.8558
# Epoch 77: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.3050 - sparse_categorical_accuracy: 0.8571 - val_loss: 1.7296 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 78/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2851 - sparse_categorical_accuracy: 0.8599
# Epoch 78: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2834 - sparse_categorical_accuracy: 0.8611 - val_loss: 1.7292 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 79/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2974 - sparse_categorical_accuracy: 0.8538
# Epoch 79: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2970 - sparse_categorical_accuracy: 0.8542 - val_loss: 1.7299 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 80/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2931 - sparse_categorical_accuracy: 0.8629
# Epoch 80: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2905 - sparse_categorical_accuracy: 0.8641 - val_loss: 1.7321 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 81/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2987 - sparse_categorical_accuracy: 0.8508
# Epoch 81: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2954 - sparse_categorical_accuracy: 0.8532 - val_loss: 1.7351 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 82/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3398 - sparse_categorical_accuracy: 0.8558
# Epoch 82: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.3403 - sparse_categorical_accuracy: 0.8552 - val_loss: 1.7320 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 83/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2702 - sparse_categorical_accuracy: 0.8750
# Epoch 83: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2710 - sparse_categorical_accuracy: 0.8750 - val_loss: 1.7292 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 84/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3087 - sparse_categorical_accuracy: 0.8548
# Epoch 84: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.3100 - sparse_categorical_accuracy: 0.8542 - val_loss: 1.7308 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 85/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3045 - sparse_categorical_accuracy: 0.8558
# Epoch 85: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3071 - sparse_categorical_accuracy: 0.8532 - val_loss: 1.7317 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 86/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3076 - sparse_categorical_accuracy: 0.8589
# Epoch 86: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.3046 - sparse_categorical_accuracy: 0.8601 - val_loss: 1.7302 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 87/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3023 - sparse_categorical_accuracy: 0.8569
# Epoch 87: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3036 - sparse_categorical_accuracy: 0.8571 - val_loss: 1.7278 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 88/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2880 - sparse_categorical_accuracy: 0.8659
# Epoch 88: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2905 - sparse_categorical_accuracy: 0.8641 - val_loss: 1.7249 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 89/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2812 - sparse_categorical_accuracy: 0.8720
# Epoch 89: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 55ms/step - loss: 0.2833 - sparse_categorical_accuracy: 0.8720 - val_loss: 1.7298 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 90/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2992 - sparse_categorical_accuracy: 0.8629
# Epoch 90: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3055 - sparse_categorical_accuracy: 0.8601 - val_loss: 1.7317 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 91/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3113 - sparse_categorical_accuracy: 0.8589
# Epoch 91: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3119 - sparse_categorical_accuracy: 0.8571 - val_loss: 1.7316 - val_sparse_categorical_accuracy: 0.5268 - lr: 1.0000e-07
# Epoch 92/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3065 - sparse_categorical_accuracy: 0.8548
# Epoch 92: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3072 - sparse_categorical_accuracy: 0.8562 - val_loss: 1.7299 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 93/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3014 - sparse_categorical_accuracy: 0.8690
# Epoch 93: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2998 - sparse_categorical_accuracy: 0.8681 - val_loss: 1.7278 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 94/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3129 - sparse_categorical_accuracy: 0.8468
# Epoch 94: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3122 - sparse_categorical_accuracy: 0.8472 - val_loss: 1.7287 - val_sparse_categorical_accuracy: 0.5179 - lr: 1.0000e-07
# Epoch 95/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2999 - sparse_categorical_accuracy: 0.8609
# Epoch 95: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3000 - sparse_categorical_accuracy: 0.8611 - val_loss: 1.7314 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 96/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3076 - sparse_categorical_accuracy: 0.8599
# Epoch 96: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 54ms/step - loss: 0.3121 - sparse_categorical_accuracy: 0.8591 - val_loss: 1.7352 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 97/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.3081 - sparse_categorical_accuracy: 0.8518
# Epoch 97: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.3055 - sparse_categorical_accuracy: 0.8532 - val_loss: 1.7347 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 98/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2913 - sparse_categorical_accuracy: 0.8669
# Epoch 98: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2885 - sparse_categorical_accuracy: 0.8681 - val_loss: 1.7360 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 99/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2916 - sparse_categorical_accuracy: 0.8599
# Epoch 99: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2925 - sparse_categorical_accuracy: 0.8581 - val_loss: 1.7314 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Epoch 100/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.2916 - sparse_categorical_accuracy: 0.8730
# Epoch 100: Current Learning Rate is 0.000000
# 32/32 [==============================] - 2s 53ms/step - loss: 0.2956 - sparse_categorical_accuracy: 0.8710 - val_loss: 1.7268 - val_sparse_categorical_accuracy: 0.5089 - lr: 1.0000e-07
# Test loss: 1.8120146989822388 / Test accuracy: 0.5120000243186951
# 4/4 [==============================] - 0s 13ms/step
# VBox(children=(Label(value='0.094 MB of 0.232 MB uploaded\r'), FloatProgress(value=0.4067175848957219, max=1.0…
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▃█▅▁▄</td></tr><tr><td>epoch</td><td>▂▄▅▆▆▇█▁▃▃▅▅▆▇▂▄▅▅▅▆▁▂▂▃▃▄▅▆▆▇▂▃▄▄▄▅▆▆▆█</td></tr><tr><td>f1_score</td><td>▂█▅▁▄</td></tr><tr><td>learning_rate</td><td>█▄▂▁▁▁▁▁▁▁█▄▃▁▁▁▁▁▁▁█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss</td><td>▂▁▂▁▇▂▁▂▂▁▂▁▂█▂▁▁▁▁▁▁▂▅▃▂▁▂▁▂▁▁▁▄▂▂▂▁▁▁▂</td></tr><tr><td>precision</td><td>▁█▆▂▄</td></tr><tr><td>recall</td><td>▃█▅▁▄</td></tr><tr><td>sparse_categorical_accuracy</td><td>▇▇████▁▇████████████████▇███████████████</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁▂█▂▂▂▂▂▂▂▁▂▂▂▂▄▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>█▇▇▇▇▃▃▅▆▇▇▇▇▇▇▇▃▁▇▇▇██████▇▇▇▇▃▆▇█▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.512</td></tr><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>1.13584</td></tr><tr><td>epoch</td><td>99</td></tr><tr><td>f1_score</td><td>0.4917</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>loss</td><td>0.29555</td></tr><tr><td>precision</td><td>0.49824</td></tr><tr><td>recall</td><td>0.51432</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.87103</td></tr><tr><td>val_loss</td><td>1.72677</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.50893</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DeepSNP_pl_1_32_5_2</strong> at: <a href='https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP/runs/rlz2txny' target="_blank">https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP/runs/rlz2txny</a><br/> View project at: <a href='https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP' target="_blank">https://wandb.ai/jaredzwx221-carnegie-mellon-univeristy/SNP_alone_feature_selected_mi_DeepSNP</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 5 other file(s)
# Find logs at: <code>./wandb/run-20241202_150016-rlz2txny/logs</code>

# %%
print("\nPerformance Metrics Across Seeds:")
print(f"Avg accuracy: {np.mean(acc):.4f} | Std: {np.std(acc):.4f}")
print(f"Avg precision: {np.mean(precision):.4f} | Std: {np.std(precision):.4f}")
print(f"Avg recall: {np.mean(recall):.4f} | Std: {np.std(recall):.4f}")
print(f"Avg F1-score: {np.mean(f1):.4f} | Std: {np.std(f1):.4f}")
# Out:
# Performance Metrics Across Seeds:
# Avg accuracy: 0.5200 | Std: 0.0299
# Avg precision: 0.5006 | Std: 0.0363
# Avg recall: 0.5221 | Std: 0.0294
# Avg F1-score: 0.4967 | Std: 0.0389

# %%
seeds

# %%
# Plot metrics for each seed
plt.figure(figsize=(10, 6))
plt.plot(range(len(seeds)), acc, marker='o', label='Accuracy')
plt.plot(range(len(seeds)), precision, marker='o', label='Precision')
plt.plot(range(len(seeds)), recall, marker='o', label='Recall')
plt.plot(range(len(seeds)), f1, marker='o', label='F1-score')
plt.title("Performance Metrics Across Random Seeds")
plt.xlabel("Random Seed")
plt.ylabel("Score")
plt.legend()
plt.grid()
plt.show()
